# %%
import numpy as np

# %%
import matplotlib.pyplot as pl
import scipy.sparse as sparse
import scipy.stats as stats

# %% [markdown]
# ### Load data

# %%
U = np.loadtxt('user_data_sample.csv', delimiter=',', skiprows=1, dtype=str)
userSet = U[:,-1]
print len(userSet), 'unique user IDs'
# Out:
# 9565 unique user IDs

# %%
#f = open('end_song_sample.csv')
L = np.loadtxt('end_song_sample.csv', delimiter=',', skiprows=1, dtype=str)

# %%
playLengths = np.array(L[:,0], dtype=int)
playEnds = np.array(L[:,-2], dtype=float)
np.save('playlengths', playLengths)
np.save('playEnds', playEnds)

# %%
users = np.array(map(dict(zip(userSet, range(len(userSet)))).get, L[:,-1]))
np.save('users', users)

# %%
def toIdx(a):
    ''' Map array elements to index representation
        a: 1-D array
        return (idx, vSet) 
    '''
    vSet = set(a)
    vMap = dict(zip(list(vSet), range(len(vSet))))
    return np.array(map(vMap.get, a), dtype=int), vSet

# %%
contexts, contextSet = toIdx(L[:,1])
np.save('contextMap', contextMap)
np.save('contexts', context)
print 'contexts:', contextSet
# Out:
# contexts: ['album', 'me', 'playlist', 'artist', 'unknown', 'app', 'search', 'collection']

# %%
tracks, trackSet = toIdx(L[:,2])
np.save('tracks', tracks)
np.save('trackSet', trackSet)
print len(trackSet), 'unique track IDs'
# Out:
# 314986 unique track IDs

# %%
products, productSet = toIdx(L[:,3])
np.save('products', products)
np.save('productSet', productSet)
print 'products:', productSet
# Out:
# products: ['basic-desktop', 'premium', 'open', 'free']

# %% [markdown]
# ###  Gender partition

# %%
n = len(userSet)
isMale = U[:,0]=='male'
nM = np.sum(isMale)
nF = n - nM
print "%d males, %d females" % (nM, nF)
# Out:
# 4979 males, 4586 females

# %%
# Index of male and female plays
users = np.load('users.npy')
idxM = np.in1d(users, np.flatnonzero(isMale))
idxF = np.invert(idxM)

# %%
print "%d female plays, %d male plays"%(idxF.sum(), idxM.sum())
# Out:
# 651412 female plays, 691479 male plays

# %%
# Re-index within each gender
usersM, setM = toIdx(users[idxM])
usersF, setF = toIdx(users[idxF])

# %% [markdown]
# ### User-song playcounts by gender

# %%
def accumulate(key1,key2,v, d1, d2):
    """
    Accumulates values for each index pair.
    a: 1-D array of ID for variable 1
    b: 1-D array of ID for variable 2
    v: 1-D array of value to accumulate
    return: m-by-n matrix where cell (i,j) sums the values from v indexed by (i,j) 
    """
    # assumes I,J,v are the same length > 0
    N = len(key1)
    print N, 'records'
    print 'dimension:', d1, d2
    out = sparse.dok_matrix((d1, d2), dtype=type(v[0]))
    for k in range(N):
        if not k%1000:
            print k, 'items processed'
        #print key1[k], key2[k]
        out[key1[k], key2[k]] += v[k]
    return out

# %%
usersM, setM = toIdx(users[idxM])
tracks = np.load('tracks.npy')
trackSet = np.load('trackSet.npy')
playLengths = np.load('playlengths.npy')
playtimeM = accumulate(usersM, tracks[idxM], playLengths, len(setM), len(trackSet))
# Out:
# 691479 records
# dimension: 4979 314986
# 0 items processed
# 500 items processed
# 1000 items processed
# 1500 items processed
# 2000 items processed
# 2500 items processed
# 3000 items processed
# 3500 items processed
# 4000 items processed
# 4500 items processed
# 5000 items processed
# 5500 items processed
# 6000 items processed
# 6500 items processed
# 7000 items processed
# 7500 items processed
# 8000 items processed
# 8500 items processed
# 9000 items processed
# 9500 items processed
# 10000 items processed
# 10500 items processed
# 11000 items processed
# 11500 items processed
# 12000 items processed
# 12500 items processed
# 13000 items processed
# 13500 items processed
# 14000 items processed
# 14500 items processed
# 15000 items processed
# 15500 items processed
# 16000 items processed
# 16500 items processed
# 17000 items processed
# 17500 items processed
# 18000 items processed
# 18500 items processed
# 19000 items processed
# 19500 items processed
# 20000 items processed
# 20500 items processed
# 21000 items processed
# 21500 items processed
# 22000 items processed
# 22500 items processed
# 23000 items processed
# 23500 items processed
# 24000 items processed
# 24500 items processed
# 25000 items processed
# 25500 items processed
# 26000 items processed
# 26500 items processed
# 27000 items processed
# 27500 items processed
# 28000 items processed
# 28500 items processed
# 29000 items processed
# 29500 items processed
# 30000 items processed
# 30500 items processed
# 31000 items processed
# 31500 items processed
# 32000 items processed
# 32500 items processed
# 33000 items processed
# 33500 items processed
# 34000 items processed
# 34500 items processed
# 35000 items processed
# 35500 items processed
# 36000 items processed
# 36500 items processed
# 37000 items processed
# 37500 items processed
# 38000 items processed
# 38500 items processed
# 39000 items processed
# 39500 items processed
# 40000 items processed
# 40500 items processed
# 41000 items processed
# 41500 items processed
# 42000 items processed
# 42500 items processed
# 43000 items processed
# 43500 items processed
# 44000 items processed
# 44500 items processed
# 45000 items processed
# 45500 items processed
# 46000 items processed
# 46500 items processed
# 47000 items processed
# 47500 items processed
# 48000 items processed
# 48500 items processed
# 49000 items processed
# 49500 items processed
# 50000 items processed
# 50500 items processed
# 51000 items processed
# 51500 items processed
# 52000 items processed
# 52500 items processed
# 53000 items processed
# 53500 items processed
# 54000 items processed
# 54500 items processed
# 55000 items processed
# 55500 items processed
# 56000 items processed
# 56500 items processed
# 57000 items processed
# 57500 items processed
# 58000 items processed
# 58500 items processed
# 59000 items processed
# 59500 items processed
# 60000 items processed
# 60500 items processed
# 61000 items processed
# 61500 items processed
# 62000 items processed
# 62500 items processed
# 63000 items processed
# 63500 items processed
# 64000 items processed
# 64500 items processed
# 65000 items processed
# 65500 items processed
# 66000 items processed
# 66500 items processed
# 67000 items processed
# 67500 items processed
# 68000 items processed
# 68500 items processed
# 69000 items processed
# 69500 items processed
# 70000 items processed
# 70500 items processed
# 71000 items processed
# 71500 items processed
# 72000 items processed
# 72500 items processed
# 73000 items processed
# 73500 items processed
# 74000 items processed
# 74500 items processed
# 75000 items processed
# 75500 items processed
# 76000 items processed
# 76500 items processed
# 77000 items processed
# 77500 items processed
# 78000 items processed
# 78500 items processed
# 79000 items processed
# 79500 items processed
# 80000 items processed
# 80500 items processed
# 81000 items processed
# 81500 items processed
# 82000 items processed
# 82500 items processed
# 83000 items processed
# 83500 items processed
# 84000 items processed
# 84500 items processed
# 85000 items processed
# 85500 items processed
# 86000 items processed
# 86500 items processed
# 87000 items processed
# 87500 items processed
# 88000 items processed
# 88500 items processed
# 89000 items processed
# 89500 items processed
# 90000 items processed
# 90500 items processed
# 91000 items processed
# 91500 items processed
# 92000 items processed
# 92500 items processed
# 93000 items processed
# 93500 items processed
# 94000 items processed
# 94500 items processed
# 95000 items processed
# 95500 items processed
# 96000 items processed
# 96500 items processed
# 97000 items processed
# 97500 items processed
# 98000 items processed
# 98500 items processed
# 99000 items processed
# 99500 items processed
# 100000 items processed
# 100500 items processed
# 101000 items processed
# 101500 items processed
# 102000 items processed
# 102500 items processed
# 103000 items processed
# 103500 items processed
# 104000 items processed
# 104500 items processed
# 105000 items processed
# 105500 items processed
# 106000 items processed
# 106500 items processed
# 107000 items processed
# 107500 items processed
# 108000 items processed
# 108500 items processed
# 109000 items processed
# 109500 items processed
# 110000 items processed
# 110500 items processed
# 111000 items processed
# 111500 items processed
# 112000 items processed
# 112500 items processed
# 113000 items processed
# 113500 items processed
# 114000 items processed
# 114500 items processed
# 115000 items processed
# 115500 items processed
# 116000 items processed
# 116500 items processed
# 117000 items processed
# 117500 items processed
# 118000 items processed
# 118500 items processed
# 119000 items processed
# 119500 items processed
# 120000 items processed
# 120500 items processed
# 121000 items processed
# 121500 items processed
# 122000 items processed
# 122500 items processed
# 123000 items processed
# 123500 items processed
# 124000 items processed
# 124500 items processed
# 125000 items processed
# 125500 items processed
# 126000 items processed
# 126500 items processed
# 127000 items processed
# 127500 items processed
# 128000 items processed
# 128500 items processed
# 129000 items processed
# 129500 items processed
# 130000 items processed
# 130500 items processed
# 131000 items processed
# 131500 items processed
# 132000 items processed
# 132500 items processed
# 133000 items processed
# 133500 items processed
# 134000 items processed
# 134500 items processed
# 135000 items processed
# 135500 items processed
# 136000 items processed
# 136500 items processed
# 137000 items processed
# 137500 items processed
# 138000 items processed
# 138500 items processed
# 139000 items processed
# 139500 items processed
# 140000 items processed
# 140500 items processed
# 141000 items processed
# 141500 items processed
# 142000 items processed
# 142500 items processed
# 143000 items processed
# 143500 items processed
# 144000 items processed
# 144500 items processed
# 145000 items processed
# 145500 items processed
# 146000 items processed
# 146500 items processed
# 147000 items processed
# 147500 items processed
# 148000 items processed
# 148500 items processed
# 149000 items processed
# 149500 items processed
# 150000 items processed
# 150500 items processed
# 151000 items processed
# 151500 items processed
# 152000 items processed
# 152500 items processed
# 153000 items processed
# 153500 items processed
# 154000 items processed
# 154500 items processed
# 155000 items processed
# 155500 items processed
# 156000 items processed
# 156500 items processed
# 157000 items processed
# 157500 items processed
# 158000 items processed
# 158500 items processed
# 159000 items processed
# 159500 items processed
# 160000 items processed
# 160500 items processed
# 161000 items processed
# 161500 items processed
# 162000 items processed
# 162500 items processed
# 163000 items processed
# 163500 items processed
# 164000 items processed
# 164500 items processed
# 165000 items processed
# 165500 items processed
# 166000 items processed
# 166500 items processed
# 167000 items processed
# 167500 items processed
# 168000 items processed
# 168500 items processed
# 169000 items processed
# 169500 items processed
# 170000 items processed
# 170500 items processed
# 171000 items processed
# 171500 items processed
# 172000 items processed
# 172500 items processed
# 173000 items processed
# 173500 items processed
# 174000 items processed
# 174500 items processed
# 175000 items processed
# 175500 items processed
# 176000 items processed
# 176500 items processed
# 177000 items processed
# 177500 items processed
# 178000 items processed
# 178500 items processed
# 179000 items processed
# 179500 items processed
# 180000 items processed
# 180500 items processed
# 181000 items processed
# 181500 items processed
# 182000 items processed
# 182500 items processed
# 183000 items processed
# 183500 items processed
# 184000 items processed
# 184500 items processed
# 185000 items processed
# 185500 items processed
# 186000 items processed
# 186500 items processed
# 187000 items processed
# 187500 items processed
# 188000 items processed
# 188500 items processed
# 189000 items processed
# 189500 items processed
# 190000 items processed
# 190500 items processed
# 191000 items processed
# 191500 items processed
# 192000 items processed
# 192500 items processed
# 193000 items processed
# 193500 items processed
# 194000 items processed
# 194500 items processed
# 195000 items processed
# 195500 items processed
# 196000 items processed
# 196500 items processed
# 197000 items processed
# 197500 items processed
# 198000 items processed
# 198500 items processed
# 199000 items processed
# 199500 items processed
# 200000 items processed
# 200500 items processed
# 201000 items processed
# 201500 items processed
# 202000 items processed
# 202500 items processed
# 203000 items processed
# 203500 items processed
# 204000 items processed
# 204500 items processed
# 205000 items processed
# 205500 items processed
# 206000 items processed
# 206500 items processed
# 207000 items processed
# 207500 items processed
# 208000 items processed
# 208500 items processed
# 209000 items processed
# 209500 items processed
# 210000 items processed
# 210500 items processed
# 211000 items processed
# 211500 items processed
# 212000 items processed
# 212500 items processed
# 213000 items processed
# 213500 items processed
# 214000 items processed
# 214500 items processed
# 215000 items processed
# 215500 items processed
# 216000 items processed
# 216500 items processed
# 217000 items processed
# 217500 items processed
# 218000 items processed
# 218500 items processed
# 219000 items processed
# 219500 items processed
# 220000 items processed
# 220500 items processed
# 221000 items processed
# 221500 items processed
# 222000 items processed
# 222500 items processed
# 223000 items processed
# 223500 items processed
# 224000 items processed
# 224500 items processed
# 225000 items processed
# 225500 items processed
# 226000 items processed
# 226500 items processed
# 227000 items processed
# 227500 items processed
# 228000 items processed
# 228500 items processed
# 229000 items processed
# 229500 items processed
# 230000 items processed
# 230500 items processed
# 231000 items processed
# 231500 items processed
# 232000 items processed
# 232500 items processed
# 233000 items processed
# 233500 items processed
# 234000 items processed
# 234500 items processed
# 235000 items processed
# 235500 items processed
# 236000 items processed
# 236500 items processed
# 237000 items processed
# 237500 items processed
# 238000 items processed
# 238500 items processed
# 239000 items processed
# 239500 items processed
# 240000 items processed
# 240500 items processed
# 241000 items processed
# 241500 items processed
# 242000 items processed
# 242500 items processed
# 243000 items processed
# 243500 items processed
# 244000 items processed
# 244500 items processed
# 245000 items processed
# 245500 items processed
# 246000 items processed
# 246500 items processed
# 247000 items processed
# 247500 items processed
# 248000 items processed
# 248500 items processed
# 249000 items processed
# 249500 items processed
# 250000 items processed
# 250500 items processed
# 251000 items processed
# 251500 items processed
# 252000 items processed
# 252500 items processed
# 253000 items processed
# 253500 items processed
# 254000 items processed
# 254500 items processed
# 255000 items processed
# 255500 items processed
# 256000 items processed
# 256500 items processed
# 257000 items processed
# 257500 items processed
# 258000 items processed
# 258500 items processed
# 259000 items processed
# 259500 items processed
# 260000 items processed
# 260500 items processed
# 261000 items processed
# 261500 items processed
# 262000 items processed
# 262500 items processed
# 263000 items processed
# 263500 items processed
# 264000 items processed
# 264500 items processed
# 265000 items processed
# 265500 items processed
# 266000 items processed
# 266500 items processed
# 267000 items processed
# 267500 items processed
# 268000 items processed
# 268500 items processed
# 269000 items processed
# 269500 items processed
# 270000 items processed
# 270500 items processed
# 271000 items processed
# 271500 items processed
# 272000 items processed
# 272500 items processed
# 273000 items processed
# 273500 items processed
# 274000 items processed
# 274500 items processed
# 275000 items processed
# 275500 items processed
# 276000 items processed
# 276500 items processed
# 277000 items processed
# 277500 items processed
# 278000 items processed
# 278500 items processed
# 279000 items processed
# 279500 items processed
# 280000 items processed
# 280500 items processed
# 281000 items processed
# 281500 items processed
# 282000 items processed
# 282500 items processed
# 283000 items processed
# 283500 items processed
# 284000 items processed
# 284500 items processed
# 285000 items processed
# 285500 items processed
# 286000 items processed
# 286500 items processed
# 287000 items processed
# 287500 items processed
# 288000 items processed
# 288500 items processed
# 289000 items processed
# 289500 items processed
# 290000 items processed
# 290500 items processed
# 291000 items processed
# 291500 items processed
# 292000 items processed
# 292500 items processed
# 293000 items processed
# 293500 items processed
# 294000 items processed
# 294500 items processed
# 295000 items processed
# 295500 items processed
# 296000 items processed
# 296500 items processed
# 297000 items processed
# 297500 items processed
# 298000 items processed
# 298500 items processed
# 299000 items processed
# 299500 items processed
# 300000 items processed
# 300500 items processed
# 301000 items processed
# 301500 items processed
# 302000 items processed
# 302500 items processed
# 303000 items processed
# 303500 items processed
# 304000 items processed
# 304500 items processed
# 305000 items processed
# 305500 items processed
# 306000 items processed
# 306500 items processed
# 307000 items processed
# 307500 items processed
# 308000 items processed
# 308500 items processed
# 309000 items processed
# 309500 items processed
# 310000 items processed
# 310500 items processed
# 311000 items processed
# 311500 items processed
# 312000 items processed
# 312500 items processed
# 313000 items processed
# 313500 items processed
# 314000 items processed
# 314500 items processed
# 315000 items processed
# 315500 items processed
# 316000 items processed
# 316500 items processed
# 317000 items processed
# 317500 items processed
# 318000 items processed
# 318500 items processed
# 319000 items processed
# 319500 items processed
# 320000 items processed
# 320500 items processed
# 321000 items processed
# 321500 items processed
# 322000 items processed
# 322500 items processed
# 323000 items processed
# 323500 items processed
# 324000 items processed
# 324500 items processed
# 325000 items processed
# 325500 items processed
# 326000 items processed
# 326500 items processed
# 327000 items processed
# 327500 items processed
# 328000 items processed
# 328500 items processed
# 329000 items processed
# 329500 items processed
# 330000 items processed
# 330500 items processed
# 331000 items processed
# 331500 items processed
# 332000 items processed
# 332500 items processed
# 333000 items processed
# 333500 items processed
# 334000 items processed
# 334500 items processed
# 335000 items processed
# 335500 items processed
# 336000 items processed
# 336500 items processed
# 337000 items processed
# 337500 items processed
# 338000 items processed
# 338500 items processed
# 339000 items processed
# 339500 items processed
# 340000 items processed
# 340500 items processed
# 341000 items processed
# 341500 items processed
# 342000 items processed
# 342500 items processed
# 343000 items processed
# 343500 items processed
# 344000 items processed
# 344500 items processed
# 345000 items processed
# 345500 items processed
# 346000 items processed
# 346500 items processed
# 347000 items processed
# 347500 items processed
# 348000 items processed
# 348500 items processed
# 349000 items processed
# 349500 items processed
# 350000 items processed
# 350500 items processed
# 351000 items processed
# 351500 items processed
# 352000 items processed
# 352500 items processed
# 353000 items processed
# 353500 items processed
# 354000 items processed
# 354500 items processed
# 355000 items processed
# 355500 items processed
# 356000 items processed
# 356500 items processed
# 357000 items processed
# 357500 items processed
# 358000 items processed
# 358500 items processed
# 359000 items processed
# 359500 items processed
# 360000 items processed
# 360500 items processed
# 361000 items processed
# 361500 items processed
# 362000 items processed
# 362500 items processed
# 363000 items processed
# 363500 items processed
# 364000 items processed
# 364500 items processed
# 365000 items processed
# 365500 items processed
# 366000 items processed
# 366500 items processed
# 367000 items processed
# 367500 items processed
# 368000 items processed
# 368500 items processed
# 369000 items processed
# 369500 items processed
# 370000 items processed
# 370500 items processed
# 371000 items processed
# 371500 items processed
# 372000 items processed
# 372500 items processed
# 373000 items processed
# 373500 items processed
# 374000 items processed
# 374500 items processed
# 375000 items processed
# 375500 items processed
# 376000 items processed
# 376500 items processed
# 377000 items processed
# 377500 items processed
# 378000 items processed
# 378500 items processed
# 379000 items processed
# 379500 items processed
# 380000 items processed
# 380500 items processed
# 381000 items processed
# 381500 items processed
# 382000 items processed
# 382500 items processed
# 383000 items processed
# 383500 items processed
# 384000 items processed
# 384500 items processed
# 385000 items processed
# 385500 items processed
# 386000 items processed
# 386500 items processed
# 387000 items processed
# 387500 items processed
# 388000 items processed
# 388500 items processed
# 389000 items processed
# 389500 items processed
# 390000 items processed
# 390500 items processed
# 391000 items processed
# 391500 items processed
# 392000 items processed
# 392500 items processed
# 393000 items processed
# 393500 items processed
# 394000 items processed
# 394500 items processed
# 395000 items processed
# 395500 items processed
# 396000 items processed
# 396500 items processed
# 397000 items processed
# 397500 items processed
# 398000 items processed
# 398500 items processed
# 399000 items processed
# 399500 items processed
# 400000 items processed
# 400500 items processed
# 401000 items processed
# 401500 items processed
# 402000 items processed
# 402500 items processed
# 403000 items processed
# 403500 items processed
# 404000 items processed
# 404500 items processed
# 405000 items processed
# 405500 items processed
# 406000 items processed
# 406500 items processed
# 407000 items processed
# 407500 items processed
# 408000 items processed
# 408500 items processed
# 409000 items processed
# 409500 items processed
# 410000 items processed
# 410500 items processed
# 411000 items processed
# 411500 items processed
# 412000 items processed
# 412500 items processed
# 413000 items processed
# 413500 items processed
# 414000 items processed
# 414500 items processed
# 415000 items processed
# 415500 items processed
# 416000 items processed
# 416500 items processed
# 417000 items processed
# 417500 items processed
# 418000 items processed
# 418500 items processed
# 419000 items processed
# 419500 items processed
# 420000 items processed
# 420500 items processed
# 421000 items processed
# 421500 items processed
# 422000 items processed
# 422500 items processed
# 423000 items processed
# 423500 items processed
# 424000 items processed
# 424500 items processed
# 425000 items processed
# 425500 items processed
# 426000 items processed
# 426500 items processed
# 427000 items processed
# 427500 items processed
# 428000 items processed
# 428500 items processed
# 429000 items processed
# 429500 items processed
# 430000 items processed
# 430500 items processed
# 431000 items processed
# 431500 items processed
# 432000 items processed
# 432500 items processed
# 433000 items processed
# 433500 items processed
# 434000 items processed
# 434500 items processed
# 435000 items processed
# 435500 items processed
# 436000 items processed
# 436500 items processed
# 437000 items processed
# 437500 items processed
# 438000 items processed
# 438500 items processed
# 439000 items processed
# 439500 items processed
# 440000 items processed
# 440500 items processed
# 441000 items processed
# 441500 items processed
# 442000 items processed
# 442500 items processed
# 443000 items processed
# 443500 items processed
# 444000 items processed
# 444500 items processed
# 445000 items processed
# 445500 items processed
# 446000 items processed
# 446500 items processed
# 447000 items processed
# 447500 items processed
# 448000 items processed
# 448500 items processed
# 449000 items processed
# 449500 items processed
# 450000 items processed
# 450500 items processed
# 451000 items processed
# 451500 items processed
# 452000 items processed
# 452500 items processed
# 453000 items processed
# 453500 items processed
# 454000 items processed
# 454500 items processed
# 455000 items processed
# 455500 items processed
# 456000 items processed
# 456500 items processed
# 457000 items processed
# 457500 items processed
# 458000 items processed
# 458500 items processed
# 459000 items processed
# 459500 items processed
# 460000 items processed
# 460500 items processed
# 461000 items processed
# 461500 items processed
# 462000 items processed
# 462500 items processed
# 463000 items processed
# 463500 items processed
# 464000 items processed
# 464500 items processed
# 465000 items processed
# 465500 items processed
# 466000 items processed
# 466500 items processed
# 467000 items processed
# 467500 items processed
# 468000 items processed
# 468500 items processed
# 469000 items processed
# 469500 items processed
# 470000 items processed
# 470500 items processed
# 471000 items processed
# 471500 items processed
# 472000 items processed
# 472500 items processed
# 473000 items processed
# 473500 items processed
# 474000 items processed
# 474500 items processed
# 475000 items processed
# 475500 items processed
# 476000 items processed
# 476500 items processed
# 477000 items processed
# 477500 items processed
# 478000 items processed
# 478500 items processed
# 479000 items processed
# 479500 items processed
# 480000 items processed
# 480500 items processed
# 481000 items processed
# 481500 items processed
# 482000 items processed
# 482500 items processed
# 483000 items processed
# 483500 items processed
# 484000 items processed
# 484500 items processed
# 485000 items processed
# 485500 items processed
# 486000 items processed
# 486500 items processed
# 487000 items processed
# 487500 items processed
# 488000 items processed
# 488500 items processed
# 489000 items processed
# 489500 items processed
# 490000 items processed
# 490500 items processed
# 491000 items processed
# 491500 items processed
# 492000 items processed
# 492500 items processed
# 493000 items processed
# 493500 items processed
# 494000 items processed
# 494500 items processed
# 495000 items processed
# 495500 items processed
# 496000 items processed
# 496500 items processed
# 497000 items processed
# 497500 items processed
# 498000 items processed
# 498500 items processed
# 499000 items processed
# 499500 items processed
# 500000 items processed
# 500500 items processed
# 501000 items processed
# 501500 items processed
# 502000 items processed
# 502500 items processed
# 503000 items processed
# 503500 items processed
# 504000 items processed
# 504500 items processed
# 505000 items processed
# 505500 items processed
# 506000 items processed
# 506500 items processed
# 507000 items processed
# 507500 items processed
# 508000 items processed
# 508500 items processed
# 509000 items processed
# 509500 items processed
# 510000 items processed
# 510500 items processed
# 511000 items processed
# 511500 items processed
# 512000 items processed
# 512500 items processed
# 513000 items processed
# 513500 items processed
# 514000 items processed
# 514500 items processed
# 515000 items processed
# 515500 items processed
# 516000 items processed
# 516500 items processed
# 517000 items processed
# 517500 items processed
# 518000 items processed
# 518500 items processed
# 519000 items processed
# 519500 items processed
# 520000 items processed
# 520500 items processed
# 521000 items processed
# 521500 items processed
# 522000 items processed
# 522500 items processed
# 523000 items processed
# 523500 items processed
# 524000 items processed
# 524500 items processed
# 525000 items processed
# 525500 items processed
# 526000 items processed
# 526500 items processed
# 527000 items processed
# 527500 items processed
# 528000 items processed
# 528500 items processed
# 529000 items processed
# 529500 items processed
# 530000 items processed
# 530500 items processed
# 531000 items processed
# 531500 items processed
# 532000 items processed
# 532500 items processed
# 533000 items processed
# 533500 items processed
# 534000 items processed
# 534500 items processed
# 535000 items processed
# 535500 items processed
# 536000 items processed
# 536500 items processed
# 537000 items processed
# 537500 items processed
# 538000 items processed
# 538500 items processed
# 539000 items processed
# 539500 items processed
# 540000 items processed
# 540500 items processed
# 541000 items processed
# 541500 items processed
# 542000 items processed
# 542500 items processed
# 543000 items processed
# 543500 items processed
# 544000 items processed
# 544500 items processed
# 545000 items processed
# 545500 items processed
# 546000 items processed
# 546500 items processed
# 547000 items processed
# 547500 items processed
# 548000 items processed
# 548500 items processed
# 549000 items processed
# 549500 items processed
# 550000 items processed
# 550500 items processed
# 551000 items processed
# 551500 items processed
# 552000 items processed
# 552500 items processed
# 553000 items processed
# 553500 items processed
# 554000 items processed
# 554500 items processed
# 555000 items processed
# 555500 items processed
# 556000 items processed
# 556500 items processed
# 557000 items processed
# 557500 items processed
# 558000 items processed
# 558500 items processed
# 559000 items processed
# 559500 items processed
# 560000 items processed
# 560500 items processed
# 561000 items processed
# 561500 items processed
# 562000 items processed
# 562500 items processed
# 563000 items processed
# 563500 items processed
# 564000 items processed
# 564500 items processed
# 565000 items processed
# 565500 items processed
# 566000 items processed
# 566500 items processed
# 567000 items processed
# 567500 items processed
# 568000 items processed
# 568500 items processed
# 569000 items processed
# 569500 items processed
# 570000 items processed
# 570500 items processed
# 571000 items processed
# 571500 items processed
# 572000 items processed
# 572500 items processed
# 573000 items processed
# 573500 items processed
# 574000 items processed
# 574500 items processed
# 575000 items processed
# 575500 items processed
# 576000 items processed
# 576500 items processed
# 577000 items processed
# 577500 items processed
# 578000 items processed
# 578500 items processed
# 579000 items processed
# 579500 items processed
# 580000 items processed
# 580500 items processed
# 581000 items processed
# 581500 items processed
# 582000 items processed
# 582500 items processed
# 583000 items processed
# 583500 items processed
# 584000 items processed
# 584500 items processed
# 585000 items processed
# 585500 items processed
# 586000 items processed
# 586500 items processed
# 587000 items processed
# 587500 items processed
# 588000 items processed
# 588500 items processed
# 589000 items processed
# 589500 items processed
# 590000 items processed
# 590500 items processed
# 591000 items processed
# 591500 items processed
# 592000 items processed
# 592500 items processed
# 593000 items processed
# 593500 items processed
# 594000 items processed
# 594500 items processed
# 595000 items processed
# 595500 items processed
# 596000 items processed
# 596500 items processed
# 597000 items processed
# 597500 items processed
# 598000 items processed
# 598500 items processed
# 599000 items processed
# 599500 items processed
# 600000 items processed
# 600500 items processed
# 601000 items processed
# 601500 items processed
# 602000 items processed
# 602500 items processed
# 603000 items processed
# 603500 items processed
# 604000 items processed
# 604500 items processed
# 605000 items processed
# 605500 items processed
# 606000 items processed
# 606500 items processed
# 607000 items processed
# 607500 items processed
# 608000 items processed
# 608500 items processed
# 609000 items processed
# 609500 items processed
# 610000 items processed
# 610500 items processed
# 611000 items processed
# 611500 items processed
# 612000 items processed
# 612500 items processed
# 613000 items processed
# 613500 items processed
# 614000 items processed
# 614500 items processed
# 615000 items processed
# 615500 items processed
# 616000 items processed
# 616500 items processed
# 617000 items processed
# 617500 items processed
# 618000 items processed
# 618500 items processed
# 619000 items processed
# 619500 items processed
# 620000 items processed
# 620500 items processed
# 621000 items processed
# 621500 items processed
# 622000 items processed
# 622500 items processed
# 623000 items processed
# 623500 items processed
# 624000 items processed
# 624500 items processed
# 625000 items processed
# 625500 items processed
# 626000 items processed
# 626500 items processed
# 627000 items processed
# 627500 items processed
# 628000 items processed
# 628500 items processed
# 629000 items processed
# 629500 items processed
# 630000 items processed
# 630500 items processed
# 631000 items processed
# 631500 items processed
# 632000 items processed
# 632500 items processed
# 633000 items processed
# 633500 items processed
# 634000 items processed
# 634500 items processed
# 635000 items processed
# 635500 items processed
# 636000 items processed
# 636500 items processed
# 637000 items processed
# 637500 items processed
# 638000 items processed
# 638500 items processed
# 639000 items processed
# 639500 items processed
# 640000 items processed
# 640500 items processed
# 641000 items processed
# 641500 items processed
# 642000 items processed
# 642500 items processed
# 643000 items processed
# 643500 items processed
# 644000 items processed
# 644500 items processed
# 645000 items processed
# 645500 items processed
# 646000 items processed
# 646500 items processed
# 647000 items processed
# 647500 items processed
# 648000 items processed
# 648500 items processed
# 649000 items processed
# 649500 items processed
# 650000 items processed
# 650500 items processed
# 651000 items processed
# 651500 items processed
# 652000 items processed
# 652500 items processed
# 653000 items processed
# 653500 items processed
# 654000 items processed
# 654500 items processed
# 655000 items processed
# 655500 items processed
# 656000 items processed
# 656500 items processed
# 657000 items processed
# 657500 items processed
# 658000 items processed
# 658500 items processed
# 659000 items processed
# 659500 items processed
# 660000 items processed
# 660500 items processed
# 661000 items processed
# 661500 items processed
# 662000 items processed
# 662500 items processed
# 663000 items processed
# 663500 items processed
# 664000 items processed
# 664500 items processed
# 665000 items processed
# 665500 items processed
# 666000 items processed
# 666500 items processed
# 667000 items processed
# 667500 items processed
# 668000 items processed
# 668500 items processed
# 669000 items processed
# 669500 items processed
# 670000 items processed
# 670500 items processed
# 671000 items processed
# 671500 items processed
# 672000 items processed
# 672500 items processed
# 673000 items processed
# 673500 items processed
# 674000 items processed
# 674500 items processed
# 675000 items processed
# 675500 items processed
# 676000 items processed
# 676500 items processed
# 677000 items processed
# 677500 items processed
# 678000 items processed
# 678500 items processed
# 679000 items processed
# 679500 items processed
# 680000 items processed
# 680500 items processed
# 681000 items processed
# 681500 items processed
# 682000 items processed
# 682500 items processed
# 683000 items processed
# 683500 items processed
# 684000 items processed
# 684500 items processed
# 685000 items processed
# 685500 items processed
# 686000 items processed
# 686500 items processed
# 687000 items processed
# 687500 items processed
# 688000 items processed
# 688500 items processed
# 689000 items processed
# 689500 items processed
# 690000 items processed
# 690500 items processed
# 691000 items processed
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# <4979x314986 sparse matrix of type '<type 'numpy.int64'>'
# 	with 371322 stored elements in Dictionary Of Keys format>

# %%
np.save('playtimeM', playtimeM.tocoo())
np.load('playtimeM.npy').flatten()[0]

# %%
playtimeF = accumulate(usersF, tracks[idxF], playLengths, len(setF), len(trackSet))
np.save('playtimeF', playtimeF.tocoo())
np.load('playtimeF.npy').flatten()[0]
# Out:
# 651412 records
# dimension: 4586 314986
# 0 items processed
# 1000 items processed
# 2000 items processed
# 3000 items processed
# 4000 items processed
# 5000 items processed
# 6000 items processed
# 7000 items processed
# 8000 items processed
# 9000 items processed
# 10000 items processed
# 11000 items processed
# 12000 items processed
# 13000 items processed
# 14000 items processed
# 15000 items processed
# 16000 items processed
# 17000 items processed
# 18000 items processed
# 19000 items processed
# 20000 items processed
# 21000 items processed
# 22000 items processed
# 23000 items processed
# 24000 items processed
# 25000 items processed
# 26000 items processed
# 27000 items processed
# 28000 items processed
# 29000 items processed
# 30000 items processed
# 31000 items processed
# 32000 items processed
# 33000 items processed
# 34000 items processed
# 35000 items processed
# 36000 items processed
# 37000 items processed
# 38000 items processed
# 39000 items processed
# 40000 items processed
# 41000 items processed
# 42000 items processed
# 43000 items processed
# 44000 items processed
# 45000 items processed
# 46000 items processed
# 47000 items processed
# 48000 items processed
# 49000 items processed
# 50000 items processed
# 51000 items processed
# 52000 items processed
# 53000 items processed
# 54000 items processed
# 55000 items processed
# 56000 items processed
# 57000 items processed
# 58000 items processed
# 59000 items processed
# 60000 items processed
# 61000 items processed
# 62000 items processed
# 63000 items processed
# 64000 items processed
# 65000 items processed
# 66000 items processed
# 67000 items processed
# 68000 items processed
# 69000 items processed
# 70000 items processed
# 71000 items processed
# 72000 items processed
# 73000 items processed
# 74000 items processed
# 75000 items processed
# 76000 items processed
# 77000 items processed
# 78000 items processed
# 79000 items processed
# 80000 items processed
# 81000 items processed
# 82000 items processed
# 83000 items processed
# 84000 items processed
# 85000 items processed
# 86000 items processed
# 87000 items processed
# 88000 items processed
# 89000 items processed
# 90000 items processed
# 91000 items processed
# 92000 items processed
# 93000 items processed
# 94000 items processed
# 95000 items processed
# 96000 items processed
# 97000 items processed
# 98000 items processed
# 99000 items processed
# 100000 items processed
# 101000 items processed
# 102000 items processed
# 103000 items processed
# 104000 items processed
# 105000 items processed
# 106000 items processed
# 107000 items processed
# 108000 items processed
# 109000 items processed
# 110000 items processed
# 111000 items processed
# 112000 items processed
# 113000 items processed
# 114000 items processed
# 115000 items processed
# 116000 items processed
# 117000 items processed
# 118000 items processed
# 119000 items processed
# 120000 items processed
# 121000 items processed
# 122000 items processed
# 123000 items processed
# 124000 items processed
# 125000 items processed
# 126000 items processed
# 127000 items processed
# 128000 items processed
# 129000 items processed
# 130000 items processed
# 131000 items processed
# 132000 items processed
# 133000 items processed
# 134000 items processed
# 135000 items processed
# 136000 items processed
# 137000 items processed
# 138000 items processed
# 139000 items processed
# 140000 items processed
# 141000 items processed
# 142000 items processed
# 143000 items processed
# 144000 items processed
# 145000 items processed
# 146000 items processed
# 147000 items processed
# 148000 items processed
# 149000 items processed
# 150000 items processed
# 151000 items processed
# 152000 items processed
# 153000 items processed
# 154000 items processed
# 155000 items processed
# 156000 items processed
# 157000 items processed
# 158000 items processed
# 159000 items processed
# 160000 items processed
# 161000 items processed
# 162000 items processed
# 163000 items processed
# 164000 items processed
# 165000 items processed
# 166000 items processed
# 167000 items processed
# 168000 items processed
# 169000 items processed
# 170000 items processed
# 171000 items processed
# 172000 items processed
# 173000 items processed
# 174000 items processed
# 175000 items processed
# 176000 items processed
# 177000 items processed
# 178000 items processed
# 179000 items processed
# 180000 items processed
# 181000 items processed
# 182000 items processed
# 183000 items processed
# 184000 items processed
# 185000 items processed
# 186000 items processed
# 187000 items processed
# 188000 items processed
# 189000 items processed
# 190000 items processed
# 191000 items processed
# 192000 items processed
# 193000 items processed
# 194000 items processed
# 195000 items processed
# 196000 items processed
# 197000 items processed
# 198000 items processed
# 199000 items processed
# 200000 items processed
# 201000 items processed
# 202000 items processed
# 203000 items processed
# 204000 items processed
# 205000 items processed
# 206000 items processed
# 207000 items processed
# 208000 items processed
# 209000 items processed
# 210000 items processed
# 211000 items processed
# 212000 items processed
# 213000 items processed
# 214000 items processed
# 215000 items processed
# 216000 items processed
# 217000 items processed
# 218000 items processed
# 219000 items processed
# 220000 items processed
# 221000 items processed
# 222000 items processed
# 223000 items processed
# 224000 items processed
# 225000 items processed
# 226000 items processed
# 227000 items processed
# 228000 items processed
# 229000 items processed
# 230000 items processed
# 231000 items processed
# 232000 items processed
# 233000 items processed
# 234000 items processed
# 235000 items processed
# 236000 items processed
# 237000 items processed
# 238000 items processed
# 239000 items processed
# 240000 items processed
# 241000 items processed
# 242000 items processed
# 243000 items processed
# 244000 items processed
# 245000 items processed
# 246000 items processed
# 247000 items processed
# 248000 items processed
# 249000 items processed
# 250000 items processed
# 251000 items processed
# 252000 items processed
# 253000 items processed
# 254000 items processed
# 255000 items processed
# 256000 items processed
# 257000 items processed
# 258000 items processed
# 259000 items processed
# 260000 items processed
# 261000 items processed
# 262000 items processed
# 263000 items processed
# 264000 items processed
# 265000 items processed
# 266000 items processed
# 267000 items processed
# 268000 items processed
# 269000 items processed
# 270000 items processed
# 271000 items processed
# 272000 items processed
# 273000 items processed
# 274000 items processed
# 275000 items processed
# 276000 items processed
# 277000 items processed
# 278000 items processed
# 279000 items processed
# 280000 items processed
# 281000 items processed
# 282000 items processed
# 283000 items processed
# 284000 items processed
# 285000 items processed
# 286000 items processed
# 287000 items processed
# 288000 items processed
# 289000 items processed
# 290000 items processed
# 291000 items processed
# 292000 items processed
# 293000 items processed
# 294000 items processed
# 295000 items processed
# 296000 items processed
# 297000 items processed
# 298000 items processed
# 299000 items processed
# 300000 items processed
# 301000 items processed
# 302000 items processed
# 303000 items processed
# 304000 items processed
# 305000 items processed
# 306000 items processed
# 307000 items processed
# 308000 items processed
# 309000 items processed
# 310000 items processed
# 311000 items processed
# 312000 items processed
# 313000 items processed
# 314000 items processed
# 315000 items processed
# 316000 items processed
# 317000 items processed
# 318000 items processed
# 319000 items processed
# 320000 items processed
# 321000 items processed
# 322000 items processed
# 323000 items processed
# 324000 items processed
# 325000 items processed
# 326000 items processed
# 327000 items processed
# 328000 items processed
# 329000 items processed
# 330000 items processed
# 331000 items processed
# 332000 items processed
# 333000 items processed
# 334000 items processed
# 335000 items processed
# 336000 items processed
# 337000 items processed
# 338000 items processed
# 339000 items processed
# 340000 items processed
# 341000 items processed
# 342000 items processed
# 343000 items processed
# 344000 items processed
# 345000 items processed
# 346000 items processed
# 347000 items processed
# 348000 items processed
# 349000 items processed
# 350000 items processed
# 351000 items processed
# 352000 items processed
# 353000 items processed
# 354000 items processed
# 355000 items processed
# 356000 items processed
# 357000 items processed
# 358000 items processed
# 359000 items processed
# 360000 items processed
# 361000 items processed
# 362000 items processed
# 363000 items processed
# 364000 items processed
# 365000 items processed
# 366000 items processed
# 367000 items processed
# 368000 items processed
# 369000 items processed
# 370000 items processed
# 371000 items processed
# 372000 items processed
# 373000 items processed
# 374000 items processed
# 375000 items processed
# 376000 items processed
# 377000 items processed
# 378000 items processed
# 379000 items processed
# 380000 items processed
# 381000 items processed
# 382000 items processed
# 383000 items processed
# 384000 items processed
# 385000 items processed
# 386000 items processed
# 387000 items processed
# 388000 items processed
# 389000 items processed
# 390000 items processed
# 391000 items processed
# 392000 items processed
# 393000 items processed
# 394000 items processed
# 395000 items processed
# 396000 items processed
# 397000 items processed
# 398000 items processed
# 399000 items processed
# 400000 items processed
# 401000 items processed
# 402000 items processed
# 403000 items processed
# 404000 items processed
# 405000 items processed
# 406000 items processed
# 407000 items processed
# 408000 items processed
# 409000 items processed
# 410000 items processed
# 411000 items processed
# 412000 items processed
# 413000 items processed
# 414000 items processed
# 415000 items processed
# 416000 items processed
# 417000 items processed
# 418000 items processed
# 419000 items processed
# 420000 items processed
# 421000 items processed
# 422000 items processed
# 423000 items processed
# 424000 items processed
# 425000 items processed
# 426000 items processed
# 427000 items processed
# 428000 items processed
# 429000 items processed
# 430000 items processed
# 431000 items processed
# 432000 items processed
# 433000 items processed
# 434000 items processed
# 435000 items processed
# 436000 items processed
# 437000 items processed
# 438000 items processed
# 439000 items processed
# 440000 items processed
# 441000 items processed
# 442000 items processed
# 443000 items processed
# 444000 items processed
# 445000 items processed
# 446000 items processed
# 447000 items processed
# 448000 items processed
# 449000 items processed
# 450000 items processed
# 451000 items processed
# 452000 items processed
# 453000 items processed
# 454000 items processed
# 455000 items processed
# 456000 items processed
# 457000 items processed
# 458000 items processed
# 459000 items processed
# 460000 items processed
# 461000 items processed
# 462000 items processed
# 463000 items processed
# 464000 items processed
# 465000 items processed
# 466000 items processed
# 467000 items processed
# 468000 items processed
# 469000 items processed
# 470000 items processed
# 471000 items processed
# 472000 items processed
# 473000 items processed
# 474000 items processed
# 475000 items processed
# 476000 items processed
# 477000 items processed
# 478000 items processed
# 479000 items processed
# 480000 items processed
# 481000 items processed
# 482000 items processed
# 483000 items processed
# 484000 items processed
# 485000 items processed
# 486000 items processed
# 487000 items processed
# 488000 items processed
# 489000 items processed
# 490000 items processed
# 491000 items processed
# 492000 items processed
# 493000 items processed
# 494000 items processed
# 495000 items processed
# 496000 items processed
# 497000 items processed
# 498000 items processed
# 499000 items processed
# 500000 items processed
# 501000 items processed
# 502000 items processed
# 503000 items processed
# 504000 items processed
# 505000 items processed
# 506000 items processed
# 507000 items processed
# 508000 items processed
# 509000 items processed
# 510000 items processed
# 511000 items processed
# 512000 items processed
# 513000 items processed
# 514000 items processed
# 515000 items processed
# 516000 items processed
# 517000 items processed
# 518000 items processed
# 519000 items processed
# 520000 items processed
# 521000 items processed
# 522000 items processed
# 523000 items processed
# 524000 items processed
# 525000 items processed
# 526000 items processed
# 527000 items processed
# 528000 items processed
# 529000 items processed
# 530000 items processed
# 531000 items processed
# 532000 items processed
# 533000 items processed
# 534000 items processed
# 535000 items processed
# 536000 items processed
# 537000 items processed
# 538000 items processed
# 539000 items processed
# 540000 items processed
# 541000 items processed
# 542000 items processed
# 543000 items processed
# 544000 items processed
# 545000 items processed
# 546000 items processed
# 547000 items processed
# 548000 items processed
# 549000 items processed
# 550000 items processed
# 551000 items processed
# 552000 items processed
# 553000 items processed
# 554000 items processed
# 555000 items processed
# 556000 items processed
# 557000 items processed
# 558000 items processed
# 559000 items processed
# 560000 items processed
# 561000 items processed
# 562000 items processed
# 563000 items processed
# 564000 items processed
# 565000 items processed
# 566000 items processed
# 567000 items processed
# 568000 items processed
# 569000 items processed
# 570000 items processed
# 571000 items processed
# 572000 items processed
# 573000 items processed
# 574000 items processed
# 575000 items processed
# 576000 items processed
# 577000 items processed
# 578000 items processed
# 579000 items processed
# 580000 items processed
# 581000 items processed
# 582000 items processed
# 583000 items processed
# 584000 items processed
# 585000 items processed
# 586000 items processed
# 587000 items processed
# 588000 items processed
# 589000 items processed
# 590000 items processed
# 591000 items processed
# 592000 items processed
# 593000 items processed
# 594000 items processed
# 595000 items processed
# 596000 items processed
# 597000 items processed
# 598000 items processed
# 599000 items processed
# 600000 items processed
# 601000 items processed
# 602000 items processed
# 603000 items processed
# 604000 items processed
# 605000 items processed
# 606000 items processed
# 607000 items processed
# 608000 items processed
# 609000 items processed
# 610000 items processed
# 611000 items processed
# 612000 items processed
# 613000 items processed
# 614000 items processed
# 615000 items processed
# 616000 items processed
# 617000 items processed
# 618000 items processed
# 619000 items processed
# 620000 items processed
# 621000 items processed
# 622000 items processed
# 623000 items processed
# 624000 items processed
# 625000 items processed
# 626000 items processed
# 627000 items processed
# 628000 items processed
# 629000 items processed
# 630000 items processed
# 631000 items processed
# 632000 items processed
# 633000 items processed
# 634000 items processed
# 635000 items processed
# 636000 items processed
# 637000 items processed
# 638000 items processed
# 639000 items processed
# 640000 items processed
# 641000 items processed
# 642000 items processed
# 643000 items processed
# 644000 items processed
# 645000 items processed
# 646000 items processed
# 647000 items processed
# 648000 items processed
# 649000 items processed
# 650000 items processed
# 651000 items processed
# <4586x314986 sparse matrix of type '<type 'numpy.int64'>'
# 	with 342285 stored elements in COOrdinate format>

# %%
playcountsM = accumulate(usersM, tracks[idxM], np.ones((len(usersM),)), len(setM), len(trackSet))
np.save('playcountsM', playcountsM.tocoo())
np.load('playcountsM.npy')
# Out:
# array(<4979x314986 sparse matrix of type '<type 'numpy.int64'>'
# 	with 383779 stored elements in COOrdinate format>, dtype=object)

# %%
playcountsF = accumulate(usersF, tracks[idxF], np.ones((len(usersF),)), len(setF), len(trackSet))
np.save('playcountsF', playcountsF.tocoo())
np.load('playcountsF.npy')
# Out:
# array(<4586x314986 sparse matrix of type '<type 'numpy.int64'>'
# 	with 353484 stored elements in COOrdinate format>, dtype=object)
